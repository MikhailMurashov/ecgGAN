# %%
import json
import matplotlib.pyplot as plt

# %%
ecg = json.load(open('C:\\Users\\mikhailm\\Documents\\study\\ecg-testing\\ecg-files\\lead_avf.json'))[16]

# %%
plt.plot(ecg)
plt.show()

# %%
new_data = list()
for i in range(320):
    new_data.append(ecg[i])
plt.plot(new_data)
plt.show()
